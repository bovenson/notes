# %%
import pandas as pd
import numpy as np

# %%
# 加载数据
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
# 查看DataFrame信息
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# 计算均值
train_df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
# 计算某一列均值
train_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
data_len = len(train_df['Age'])

# %%
w = np.random.rand(data_len)
print(w)
# Out:
# [  7.05283681e-01   8.83098097e-01   7.46404051e-01   2.69981784e-01
#    5.43277119e-01   3.06413714e-01   4.54433132e-01   8.53314161e-01
#    1.26407434e-01   3.99494638e-01   4.14139470e-01   6.37595831e-01
#    8.73406327e-01   3.85742515e-01   3.14442826e-01   7.85866210e-01
#    1.81380051e-01   7.45167323e-01   6.04888424e-01   8.04524986e-01
#    9.47489574e-01   8.52983626e-01   3.15266331e-01   9.16270026e-01
#    1.31470699e-01   7.45107341e-01   5.97886837e-01   9.21079559e-01
#    6.62929911e-01   4.69936803e-01   5.76262987e-01   6.14221476e-01
#    9.73221681e-01   6.86676330e-01   7.54851598e-03   8.02262486e-01
#    2.01576568e-01   7.03068487e-01   9.94816428e-01   7.15146426e-01
#    4.47226989e-01   9.63102616e-01   5.30483383e-01   9.15601101e-01
#    4.20020835e-01   8.46536002e-01   5.39413636e-02   4.05697551e-02
#    6.91493996e-01   8.93337524e-01   5.46307961e-01   3.29641627e-01
#    8.95629232e-01   8.67421581e-01   2.49575284e-01   9.37321472e-01
# ...
